# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('DailyDelhiClimateTest.csv')

# %%
df.head()
# Out:
#          date   meantemp   humidity  wind_speed  meanpressure
# 0  2017-01-01  15.913043  85.869565    2.743478     59.000000
# 1  2017-01-02  18.500000  77.222222    2.894444   1018.277778
# 2  2017-01-03  17.111111  81.888889    4.016667   1018.333333
# 3  2017-01-04  18.700000  70.050000    4.545000   1015.700000
# 4  2017-01-05  18.388889  74.944444    3.300000   1014.333333

# %%
df = df.iloc[:,:2]

# %%
df.head()
# Out:
#          date   meantemp
# 0  2017-01-01  15.913043
# 1  2017-01-02  18.500000
# 2  2017-01-03  17.111111
# 3  2017-01-04  18.700000
# 4  2017-01-05  18.388889

# %%
plt.scatter(df['date'],df['meantemp'], color='red')

# %%
avr = df['meantemp'].ewm(alpha=0.9).mean()

# %%
avr2 = df['meantemp'].ewm(alpha=0.1).mean()
avr3 = df['meantemp'].ewm(alpha=0.05).mean()
avr4 = df['meantemp'].ewm(alpha=0.5).mean()

# %%
avr
# Out:
# 0      15.913043
# 1      18.264822
# 2      17.225443
# 3      18.552677
# 4      18.405266
#          ...
# 109    34.403401
# 110    34.265340
# 111    33.036534
# 112    32.891153
# 113    32.089115
# Name: meantemp, Length: 114, dtype: float64

# %%
df['ewma']=avr

# %%
df.head()
# Out:
#          date   meantemp       ewma
# 0  2017-01-01  15.913043  15.913043
# 1  2017-01-02  18.500000  18.264822
# 2  2017-01-03  17.111111  17.225443
# 3  2017-01-04  18.700000  18.552677
# 4  2017-01-05  18.388889  18.405266

# %%
plt.scatter(df['date'],df['meantemp'], color='red')
plt.plot(df['date'],avr,color='black', label='alpha=0.9')
plt.plot(df['date'],avr2,color='green',label='alpha=0.1')
plt.plot(df['date'],avr3,color='yellow',label='alpha=0.05')
plt.plot(df['date'],avr4,color='blue',label='alpha=0.98')

plt.legend()
